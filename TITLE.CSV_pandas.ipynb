# %% [markdown]
# # title.csv , new data set # pandas

# %%
import pandas as pd

# %%
titles=pd.read_csv('https://raw.githubusercontent.com/DataScience75/Top_mentor_projects_Datasets/main/titles.csv')

# %%
titles
# Out:
#                                        title  year
# 0                             The Rising Son  1990
# 1                    The Thousand Plane Raid  1969
# 2                           Crucea de piatra  1993
# 3                                    Country  2000
# 4                                 Gaiking II  2011
# ...                                      ...   ...
# 230616                 Nobody Waved Good-bye  1964
# 230617                                 E yue  2005
# 230618                          Lakota Girls  2015
# 230619                        Kroniki domowe  1997
# 230620  Death in the Valley of Good and Evil  2018
#
# [230621 rows x 2 columns]

# %%
print(titles.head())
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
titles.shape
# Out:
# (230621, 2)

# %%
titles.columns
# Out:
# Index(['title', 'year'], dtype='object')

# %%
print(titles.dtypes)
# Out:
# title    object
# year      int64
# dtype: object

# %%
titles['title'].value_counts()
# Out:
# title
# Hamlet                                  18
# Carmen                                  16
# Macbeth                                 15
# The Outsider                            12
# The Three Musketeers                    11
#                                         ..
# Quo Vadis, Baby?                         1
# El idioma imposible                      1
# Pyromaniac                               1
# Tied in Blood                            1
# Death in the Valley of Good and Evil     1
# Name: count, Length: 210937, dtype: int64

# %%
titles['title'].unique()
# Out:
# array(['The Rising Son', 'The Thousand Plane Raid', 'Crucea de piatra',
#        ..., 'Lakota Girls', 'Kroniki domowe',
#        'Death in the Valley of Good and Evil'], dtype=object)

# %%
titles['title'].nunique()
# Out:
# 210937

# %%
titles['year'].min()
# Out:
# 1894

# %%
titles['year'].max()
# Out:
# 2026

# %%
y_2007= titles[titles['year']== 2007].nunique()

# %%
titles.head(100)
# Out:
#                                                 title  year
# 0                                      The Rising Son  1990
# 1                             The Thousand Plane Raid  1969
# 2                                    Crucea de piatra  1993
# 3                                             Country  2000
# 4                                          Gaiking II  2011
# ..                                                ...   ...
# 95  The Oscar Nominated Short Films 2016: Live Action  2016
# 96                        Luchadores de las estrellas  1992
# 97                                    Shooting Clerks  2016
# 98                                         El segundo  2004
# 99                                 The World Moves On  1934
#
# [100 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 print(y_2007['title'].nunique())
#
# AttributeError: 'numpy.int64' object has no attribute 'nunique'

# %%
titles
# Out:
#                                        title  year
# 0                             The Rising Son  1990
# 1                    The Thousand Plane Raid  1969
# 2                           Crucea de piatra  1993
# 3                                    Country  2000
# 4                                 Gaiking II  2011
# ...                                      ...   ...
# 230616                 Nobody Waved Good-bye  1964
# 230617                                 E yue  2005
# 230618                          Lakota Girls  2015
# 230619                        Kroniki domowe  1997
# 230620  Death in the Valley of Good and Evil  2018
#
# [230621 rows x 2 columns]

# %%
titles[titles['year']== 2007].nunique()
# Out:
# title    4347
# year        1
# dtype: int64

# %%
titles.isnull()
# Out:
#         title   year
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# ...       ...    ...
# 230616  False  False
# 230617  False  False
# 230618  False  False
# 230619  False  False
# 230620  False  False
#
# [230621 rows x 2 columns]

# %%
titles.isnull().sum()
# Out:
# title    1
# year     0
# dtype: int64

# %%
titles[titles['title'].isnull()]
titles.shape
# Out:
# (230621, 2)

# %%
titles.dropna()
# Out:
#                                        title  year
# 0                             The Rising Son  1990
# 1                    The Thousand Plane Raid  1969
# 2                           Crucea de piatra  1993
# 3                                    Country  2000
# 4                                 Gaiking II  2011
# ...                                      ...   ...
# 230616                 Nobody Waved Good-bye  1964
# 230617                                 E yue  2005
# 230618                          Lakota Girls  2015
# 230619                        Kroniki domowe  1997
# 230620  Death in the Valley of Good and Evil  2018
#
# [230620 rows x 2 columns]

# %%
titles.shape
# Out:
# (230621, 2)

# %%
titles.dropna()
# Out:
#                                        title  year
# 0                             The Rising Son  1990
# 1                    The Thousand Plane Raid  1969
# 2                           Crucea de piatra  1993
# 3                                    Country  2000
# 4                                 Gaiking II  2011
# ...                                      ...   ...
# 230616                 Nobody Waved Good-bye  1964
# 230617                                 E yue  2005
# 230618                          Lakota Girls  2015
# 230619                        Kroniki domowe  1997
# 230620  Death in the Valley of Good and Evil  2018
#
# [230620 rows x 2 columns]

# %%
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
titles.loc[1000]
# Out:
# title    La boda de Rosario
# year                   1929
# Name: 1000, dtype: object

# %%
titles.loc[[1,10,100,1000]]
# Out:
#                         title  year
# 1     The Thousand Plane Raid  1969
# 10              Slave by Name  2017
# 100              La puritaine  1986
# 1000       La boda de Rosario  1929

# %%
titles.loc[100],
# Out:
# (title    La puritaine
#  year             1986
#  Name: 100, dtype: object,)

# %%
titles.loc[10:100]
# Out:
#                            title  year
# 10                 Slave by Name  2017
# 11                The Abductress  2014
# 12      Poka Makorer Ghar Bosoti  1996
# 13                     Hi, Buddy  1943
# 14               Los siete locos  1973
# ..                           ...   ...
# 96   Luchadores de las estrellas  1992
# 97               Shooting Clerks  2016
# 98                    El segundo  2004
# 99            The World Moves On  1934
# 100                 La puritaine  1986
#
# [91 rows x 2 columns]

# %%
titles.loc[10:100:2]
# Out:
#                                        title  year
# 10                             Slave by Name  2017
# 12                  Poka Makorer Ghar Bosoti  1996
# 14                           Los siete locos  1973
# 16                     Io sono un autarchico  1976
# 18                                Mahapurush  1965
# 20                                    Patria  1917
# 22               Ang pumatay ng dahil sa iyo  1989
# 24                             The Syndicate  2011
# 26                              Arrive Alive  1990
# 28   The Majestic Life of Queen Elizabeth II  2013
# 30                                Dreamscape  2011
# 32                         The Hidden Corner  2016
# 34                                 The Court  1998
# 36                            Dressing Table  2016
# 38                                   Pruebas  2011
# 40                                  Safe Sex  1999
# 42                        The Fair Pretender  1918
# ...

# %%
titles.loc[10:100:2,['title']]
# Out:
#                                        title
# 10                             Slave by Name
# 12                  Poka Makorer Ghar Bosoti
# 14                           Los siete locos
# 16                     Io sono un autarchico
# 18                                Mahapurush
# 20                                    Patria
# 22               Ang pumatay ng dahil sa iyo
# 24                             The Syndicate
# 26                              Arrive Alive
# 28   The Majestic Life of Queen Elizabeth II
# 30                                Dreamscape
# 32                         The Hidden Corner
# 34                                 The Court
# 36                            Dressing Table
# 38                                   Pruebas
# 40                                  Safe Sex
# 42                        The Fair Pretender
# 44                               Mavi boncuk
# 46                                Torn Apart
# 48                                    Stolen
# ...

# %%
t1=titles.set_index('year')

# %%
t1.loc[1990]
# Out:
#                                            title
# year
# 1990                              The Rising Son
# 1990                                Arrive Alive
# 1990  The Neverending Story II: The Next Chapter
# 1990                                  Torn Apart
# 1990                          Thieves of Fortune
# ...                                          ...
# 1990                          Happily Ever After
# 1990                    Al Niaba Tatlob Al Baraa
# 1990                              Tsikhe-Simagre
# 1990                     3 Men and a Little Lady
# 1990                        La zona del silencio
#
# [2290 rows x 1 columns]

# %%
t1.loc[2000]
# Out:
#                                 title
# year
# 2000                          Country
# 2000                    Meigui xuanwo
# 2000              Sabse Bada Be-Imaan
# 2000                         Daybreak
# 2000            Ek Anari Duja Khiladi
# ...                               ...
# 2000         Belia we demagho el alia
# 2000                Postmark Paradise
# 2000  How to Kill Your Neighbor's Dog
# 2000                      Nagadevathe
# 2000           A Thousand Days a Year
#
# [2736 rows x 1 columns]

# %%
titles.sort_values('title')
# Out:
#                           title  year
# 142172         #1 Serial Killer  2013
# 63554                      #227  2020
# 162347                       #5  2013
# 86433                #50Fathers  2015
# 71805                       #66  2015
# ...                         ...   ...
# 25115   xXx: State of the Union  2005
# 224748                        y  2016
# 219972     yek taebir asheghane  2017
# 63683         zire saghfe doodi  2017
# 209194                      NaN  2015
#
# [230621 rows x 2 columns]

# %%
t1.sort_index()
# Out:
#                                                title
# year
# 1894                                      Miss Jerry
# 1898                              The Startled Lover
# 1899  Reproduction of the Corbett and Jeffries Fight
# 1900                           Soldiers of the Cross
# 1900                        Trouble in Hogan's Alley
# ...                                              ...
# 2023                                       Xenomorph
# 2023                                       Interplay
# 2024                      The Snowman and the Falcon
# 2025                                      Gods Heart
# 2026                               Settling of Score
#
# [230621 rows x 1 columns]

# %%
titles['year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
titles['year'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
titles['year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
titles['title'].value_counts().plot()
# Out:
# <Axes: xlabel='title'>

# %%
titles['year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
df1=pd.DataFrame({'ID':[1,2,3,4], 'NAME': ['A','B','C','D']})

# %% [markdown]
# df1

# %%
df1
# Out:
#    ID NAME
# 0   1    A
# 1   2    B
# 2   3    C
# 3   4    D
